# %%
import os
import numpy as np
import pandas as pd
from pprint import pprint

# %%
import geopandas as gpd

# %% [markdown]
# ## Loading the dataset

# %%
FILE_PATH = "../data/raw/0066221-200221144449610.csv"

# %%
raw_dataframe = pd.read_csv(FILE_PATH, sep='\t')
# Out:
# /home/christian/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (45,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
raw_dataframe.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
raw_dataframe.iloc[:, 0:10].head()
# Out:
#        gbifID                            datasetKey  \
# 0  1919827662  7e380070-f762-11e1-a439-00145eb45e9a
# 1  1919665488  7e380070-f762-11e1-a439-00145eb45e9a
# 2  1919827577  7e380070-f762-11e1-a439-00145eb45e9a
# 3  1919665451  7e380070-f762-11e1-a439-00145eb45e9a
# 4  1919828333  7e380070-f762-11e1-a439-00145eb45e9a
#
#                            occurrenceID   kingdom    phylum     class  \
# 0  ba4db66d-1e1c-4c29-bd47-705c2251fcd0  Animalia  Chordata  Mammalia
# 1  bf41c851-db96-45ce-8913-aada3279bbd0  Animalia  Chordata  Mammalia
# 2  318dfa20-1c0a-467f-a06f-7c8b84aae887  Animalia  Chordata  Mammalia
# 3  d99a95b0-8d00-429f-834e-fbad20c9703f  Animalia  Chordata  Mammalia
# 4  1cbe2220-0068-4f0e-8b85-2f7d3bb88da9  Animalia  Chordata  Mammalia
#
#       order          family        genus                species
# 0  Primates        Atelidae     Alouatta      Alouatta palliata
# 1  Rodentia      Cricetidae       Akodon          Akodon mollis
# ...

# %%
raw_dataframe.iloc[:, 10:20].head()
# Out:
#   infraspecificEpithet   taxonRank  \
# 0                  NaN     SPECIES
# 1                  NaN     SPECIES
# 2            lagonotus  SUBSPECIES
# 3                  NaN     SPECIES
# 4                  NaN     SPECIES
#
#                                       scientificName  \
# 0                     Alouatta palliata (Gray, 1849)
# 1                         Akodon mollis Thomas, 1894
# 2  Saguinus fuscicollis lagonotus (Jiménez de la ...
# 3                         Akodon mollis Thomas, 1894
# 4                   Ateles paniscus (Linnaeus, 1758)
#
#            verbatimScientificName verbatimScientificNameAuthorship  \
# 0               Alouatta palliata                              NaN
# 1                   Akodon mollis                              NaN
# 2  Saguinus fuscicollis lagonotus                              NaN
# 3                   Akodon mollis                              NaN
# 4                 Ateles paniscus                              NaN
#
# ...

# %%
raw_dataframe.iloc[:, 20:30].head()
# Out:
#                        publishingOrgKey  decimalLatitude  decimalLongitude  \
# 0  19456090-b49a-11d8-abeb-b8a03c50a862          -0.0333          -78.9833
# 1  19456090-b49a-11d8-abeb-b8a03c50a862          -2.8708          -79.1000
# 2  19456090-b49a-11d8-abeb-b8a03c50a862          -1.4667          -78.1167
# 3  19456090-b49a-11d8-abeb-b8a03c50a862          -2.8800          -79.2500
# 4  19456090-b49a-11d8-abeb-b8a03c50a862          -2.0000          -66.0000
#
#    coordinateUncertaintyInMeters  coordinatePrecision  elevation  \
# 0                            NaN                  NaN     762.00
# 1                            NaN                  NaN    2700.00
# 2                            NaN                  NaN    1097.28
# 3                            NaN                  NaN    3800.00
# 4                            NaN                  NaN        NaN
#
#    elevationAccuracy  depth  depthAccuracy            eventDate
# ...

# %%
raw_dataframe["countryCode"].value_counts()
# Out:
# CO    85182
# VE    24955
# PA    17775
# EC    16421
# PE     3082
# BR      547
# BQ       64
# CW       43
# Name: countryCode, dtype: int64
